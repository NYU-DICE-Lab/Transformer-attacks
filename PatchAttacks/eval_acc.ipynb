# %%
import pickle

f1 = '/scratch/gbj221/transformer_results_new/output_mt_vit224_it_100_mp_20_ni_1000_lr_0.01_ps_16/ks.pkl'
f2 = '/scratch/gbj221/transformer_results_new/output_mt_wide-resnet_it_100_mp_20_ni_1000_lr_0.01_ps_16/ks.pkl'
with open(f2, 'rb') as f:
    data = pickle.load(f)

# %%
import numpy as np

# %%
data
# Out:
# {557: (1, 20),
#  558: (1, 20),
#  559: (0, 20),
#  560: (0, 20),
#  561: (0, 20),
#  562: (0, 20),
#  563: (1, 20),
#  564: (1, 20),
#  565: (0, 20),
#  566: (0, 20),
#  567: (1, 20),
#  568: (1, 20),
#  569: (0, 20),
#  570: (1, 20),
#  571: (0, 20),
#  572: (0, 20),
#  573: (0, 20),
#  574: (0, 20),
#  575: (0, 20),
#  576: (0, 20),
#  577: (0, 20),
#  578: (0, 20),
#  579: (0, 20),
#  580: (0, 20),
#  581: (0, 20),
#  582: (1, 20),
#  583: (1, 20),
#  584: (1, 20),
#  585: (0, 20),
#  586: (0, 20),
#  587: (1, 20),
#  588: (0, 20),
#  589: (1, 20),
#  590: (0, 20),
#  591: (1, 20),
#  592: (1, 20),
#  593: (0, 20),
#  594: (0, 20),
#  595: (1, 20),
#  596: (1, 20),
#  597: (1, 20),
#  598: (0, 20),
#  599: (0, 20),
#  600: (1, 20),
#  601: (1, 20),
#  602: (1, 20),
#  603: (0, 20),
#  604: (0, 20),
#  605: (1, 20),
#  606: (0, 20),
#  607: (0, 20),
#  608: (1, 20),
#  609: (0, 20),
#  610: (0, 20),
#  611: (1, 20),
#  612: (1, 20),
#  613: (1, 20),
#  614: (0, 20),
# ...

# %%
data_arr = np.zeros([1000,2])
for i in range(1000):
    data_arr[i,:,] = data[i]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-7c0aff421fa7> in <module>
#       1 data_arr = np.zeros([1000,2])
#       2 for i in range(1000):
# ----> 3     data_arr[i,:,] = data[i]
#
# KeyError: 0

# %%
np.sum(data_arr[:,0])/10
# Out:
# 35.9
